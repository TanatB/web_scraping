# %%
import pandas as pd
from pyspark.sql import SparkSession

# %%
df = pd.read_parquet("datasets/products.parquet")

# %%
df.head()
# Out:
#                             product_id      product_title  handle  \
# 0  gid://shopify/Product/7421688938547  รองเท้าผู้ชาย 530  530-23
# 1  gid://shopify/Product/7421688938547  รองเท้าผู้ชาย 530  530-23
# 2  gid://shopify/Product/7421688938547  รองเท้าผู้ชาย 530  530-23
# 3  gid://shopify/Product/7421688938547  รองเท้าผู้ชาย 530  530-23
# 4  gid://shopify/Product/7421688938547  รองเท้าผู้ชาย 530  530-23
#
#                                          description product_type  \
# 0  รองเท้าผ้าใบรุ่น 530 เป็นการย้อนยุคของรองเท้าว...      รองเท้า
# 1  รองเท้าผ้าใบรุ่น 530 เป็นการย้อนยุคของรองเท้าว...      รองเท้า
# 2  รองเท้าผ้าใบรุ่น 530 เป็นการย้อนยุคของรองเท้าว...      รองเท้า
# 3  รองเท้าผ้าใบรุ่น 530 เป็นการย้อนยุคของรองเท้าว...      รองเท้า
# 4  รองเท้าผ้าใบรุ่น 530 เป็นการย้อนยุคของรองเท้าว...      รองเท้า
#
#         vendor                                               tags  min_price  \
# 0  New Balance  category__DYANMIC_MY_CAMPAIGN_1010PROMO, categ...     3900.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17162 entries, 0 to 17161
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        17162 non-null  str
#  1   product_title     17162 non-null  str
#  2   handle            17162 non-null  str
#  3   description       17162 non-null  str
#  4   product_type      17162 non-null  str
#  5   vendor            17162 non-null  str
#  6   tags              17162 non-null  str
#  7   min_price         17162 non-null  float64
#  8   max_price         17162 non-null  float64
#  9   currency          17162 non-null  str
#  10  variant_id        17162 non-null  str
#  11  variant_title     17162 non-null  str
#  12  size              17162 non-null  str
#  13  color             17162 non-null  str
#  14  variant_price     17162 non-null  float64
#  15  compare_at_price  17162 non-null  float64
#  16  available         17162 non-null  bool
# ...

# %%
spark = SparkSession.builder.appName("jd_sports_spark_session").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/04 09:21:38 WARN Utils: Your hostname, TANATB-PC, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/05/04 09:21:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/04 09:21:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark_df = spark.read.format('parquet') \
    .option('header', True) \
    .load('datasets/products.parquet')

# %%
spark_df.show()
# Out:
# +--------------------+--------------------+--------+--------------------+------------+-----------+--------------------+---------+---------+--------+--------------------+-------------+----+-----+-------------+----------------+---------+--------------------+
# |          product_id|       product_title|  handle|         description|product_type|     vendor|                tags|min_price|max_price|currency|          variant_id|variant_title|size|color|variant_price|compare_at_price|available|           image_url|
# +--------------------+--------------------+--------+--------------------+------------+-----------+--------------------+---------+---------+--------+--------------------+-------------+----+-----+-------------+----------------+---------+--------------------+
# ...

# %%
spark_df.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_title: string (nullable = true)
#  |-- handle: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- vendor: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- min_price: double (nullable = true)
#  |-- max_price: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- variant_id: string (nullable = true)
#  |-- variant_title: string (nullable = true)
#  |-- size: string (nullable = true)
#  |-- color: string (nullable = true)
#  |-- variant_price: double (nullable = true)
#  |-- compare_at_price: double (nullable = true)
#  |-- available: boolean (nullable = true)
#  |-- image_url: string (nullable = true)
